# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # data clean & pre-processing
# dealing with missing data

# %%
titanic.isna().sum()  #returns the number of missing values in each column.
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic['Age'] = titanic['Age'].fillna(titanic['Age'].mean())  #to fill missing value

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic.drop("Cabin" , axis=1 , inplace=True ) #to remove this column from table

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
titanic['Sex'].value_counts()   # to determine number of male and female
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic['Embarked'].value_counts()   # to determine number of embarked
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
sex = pd.get_dummies(titanic['Sex'] , drop_first=True)
sex
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
emb = pd.get_dummies(titanic['Embarked'] )
emb
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
titanic=pd.concat([titanic,sex,emb],axis=1)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic.drop(['PassengerId' ,'Name' , 'Sex' , 'Ticket' ,'Embarked'] , axis = 1 , inplace=True)

# %%
titanic
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  male  C  Q  S
# 0           0       3  22.000000      1      0   7.2500     1  0  0  1
# 1           1       1  38.000000      1      0  71.2833     0  1  0  0
# 2           1       3  26.000000      0      0   7.9250     0  0  0  1
# 3           1       1  35.000000      1      0  53.1000     0  0  0  1
# 4           0       3  35.000000      0      0   8.0500     1  0  0  1
# ..        ...     ...        ...    ...    ...      ...   ... .. .. ..
# 886         0       2  27.000000      0      0  13.0000     1  0  0  1
# 887         1       1  19.000000      0      0  30.0000     0  0  0  1
# 888         0       3  29.699118      1      2  23.4500     0  0  0  1
# 889         1       1  26.000000      0      0  30.0000     1  1  0  0
# 890         0       3  32.000000      0      0   7.7500     1  0  1  0
#
# [891 rows x 10 columns]

# %%
titanic.rename(columns={'male': 'Gender'},inplace=True)  #to change name of sthings
titanic
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  Gender  C  Q  S
# 0           0       3  22.000000      1      0   7.2500       1  0  0  1
# 1           1       1  38.000000      1      0  71.2833       0  1  0  0
# 2           1       3  26.000000      0      0   7.9250       0  0  0  1
# 3           1       1  35.000000      1      0  53.1000       0  0  0  1
# 4           0       3  35.000000      0      0   8.0500       1  0  0  1
# ..        ...     ...        ...    ...    ...      ...     ... .. .. ..
# 886         0       2  27.000000      0      0  13.0000       1  0  0  1
# 887         1       1  19.000000      0      0  30.0000       0  0  0  1
# 888         0       3  29.699118      1      2  23.4500       0  0  0  1
# 889         1       1  26.000000      0      0  30.0000       1  1  0  0
# 890         0       3  32.000000      0      0   7.7500       1  0  1  0
#
# [891 rows x 10 columns]

# %% [markdown]
# # Exploratory Data analysis

# %%
# %matplotlib inline

# %%
sns.countplot(x='Survived',data=titanic)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',data=titanic , hue='Gender' , palette='pastel')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
titanic['Age'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # building our model
# train/test split data

# %%
titanic
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  Gender  C  Q  S
# 0           0       3  22.000000      1      0   7.2500       1  0  0  1
# 1           1       1  38.000000      1      0  71.2833       0  1  0  0
# 2           1       3  26.000000      0      0   7.9250       0  0  0  1
# 3           1       1  35.000000      1      0  53.1000       0  0  0  1
# 4           0       3  35.000000      0      0   8.0500       1  0  0  1
# ..        ...     ...        ...    ...    ...      ...     ... .. .. ..
# 886         0       2  27.000000      0      0  13.0000       1  0  0  1
# 887         1       1  19.000000      0      0  30.0000       0  0  0  1
# 888         0       3  29.699118      1      2  23.4500       0  0  0  1
# 889         1       1  26.000000      0      0  30.0000       1  1  0  0
# 890         0       3  32.000000      0      0   7.7500       1  0  1  0
#
# [891 rows x 10 columns]

# %%
x = titanic.drop('Survived',axis=1)
y = titanic['Survived']

# %%
x
# Out:
#      Pclass        Age  SibSp  Parch     Fare  Gender  C  Q  S
# 0         3  22.000000      1      0   7.2500       1  0  0  1
# 1         1  38.000000      1      0  71.2833       0  1  0  0
# 2         3  26.000000      0      0   7.9250       0  0  0  1
# 3         1  35.000000      1      0  53.1000       0  0  0  1
# 4         3  35.000000      0      0   8.0500       1  0  0  1
# ..      ...        ...    ...    ...      ...     ... .. .. ..
# 886       2  27.000000      0      0  13.0000       1  0  0  1
# 887       1  19.000000      0      0  30.0000       0  0  0  1
# 888       3  29.699118      1      2  23.4500       0  0  0  1
# 889       1  26.000000      0      0  30.0000       1  1  0  0
# 890       3  32.000000      0      0   7.7500       1  0  1  0
#
# [891 rows x 9 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 train_test_split()
#
# NameError: name 'train_test_split' is not defined
